# %% [markdown]
# # © Artur Czarnecki. All rights reserved.
# # Integrax framework – proprietary and confidential.
# # Use, modification, or distribution without written permission is prohibited.

# %%
import sys, os
sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), "../..")))

import sys
from pathlib import Path

# # Znajdź najbliższy katalog nadrzędny, który zawiera pakiet "RAG"
# p = Path.cwd().resolve()
# while True:
#     if (p / "RAG").is_dir():
#         sys.path.insert(0, str(p))
#         break
#     if p.parent == p:
#         raise RuntimeError("Nie znalazłem katalogu z folderem 'RAG' powyżej bieżącego notatnika.")
#     p = p.parent


from intergrax.supervisor.supervisor import IntergraxSupervisor, SupervisorConfig, SupervisorPromptPack
from intergrax.llm.llm_adapters import LLMAdapterRegistry
from intergrax.rag.embedding_manager import IntergraxEmbeddingManager
from langchain_ollama import ChatOllama
from components.compliance_checker import compliance_checker
from components.cost_estimator import cost_estimator
from components.final_summary import final_summary
from applications.UXAuditAgent.components.general_knowledge import general_intergrax_knowledge
from components.project_manager import project_manager
from components.ux_audit import ux_audit


# --- LLM adapter (Ollama) ---
adapter = LLMAdapterRegistry.create(
    name="ollama",
    chat=ChatOllama(model="llama3.1:latest"),
)

# --- Zasoby (opcjonalnie) ---
resources = {
    # "retriever": intergraxRagRetriever(...),
    # "ranker": intergraxReRanker(...),
}

# --- Rejestr komponentów ---
components = [
    general_intergrax_knowledge,
    ux_audit,
    final_summary,
    project_manager,
    final_summary,
    compliance_checker,
    cost_estimator,
]

embed_manager = IntergraxEmbeddingManager(
    verbose=True,
    provider="ollama",
    model_name="rjmalagon/gte-qwen2-1.5b-instruct-embed-f16:latest", 
    assume_ollama_dim=1536)

# --- Supervisor z fallback + finally ---
cfg = SupervisorConfig(
    llm_adapter=adapter,
    components=components,
    heuristic_enable=False,
    debug=True,
    pass_temperature=False,
    pass_max_tokens=False,
    resources=resources,

    # runtime fallback only when a step has no component:
    fallback_component="Generalny",
    fallback_on_miss=True,

    # two-stage planner (decompose -> per-step assign)
    planner_mode="two_stage",
    plan_retries=2,
    assign_retries=2,
    assign_self_consistency=3,
    assign_threshold=0.50,          # zacznij luźniej, potem 0.6-0.7
    skip_on_low_confidence=False,   # zobacz przypisania nawet przy niskiej ufności
)

# --- Zapytanie testowe (jeden string) ---
query = (
    "Wykonaj następujące czynności wg podanej kolejności i warunków: "
    "1. Na podstawie przekazanych makiet FIGMY wciel się w rolę UX Audytora, "
    "który analizuje makiety pod kątem poprawności w logice i działaniu zaprojektowanej aplikacji. "
    "2. Sprawdź czy lista zmian jest zgodna z polityką prywatności firmy i z regulaminami. "
    "3. Przygotuj raport podsumowujący i przedstaw go Project Managerowi. "
    "4. Jeżeli PM odrzuci projekt — zrób krótkie podsumowanie i zakończ. Jeżeli go zaakceptuje, przejdź dalej. "
    "5. Wyciągnij raport finansowy za zeszły kwartał i oceń, czy budżet pozwala na te zmiany; "
    "jeśli koszt zmian < 2 procent budżetu — zatwierdź. "
    "6. Na koniec przygotuj pełny raport ze wszystkich kroków, działań i decyzji."
)

supervisor = IntergraxSupervisor(cfg)
plan = supervisor.plan(query)
supervisor.print_plan(plan)
state = supervisor.execute_plan(plan=plan, query=query, verbose=True)
# Out:
# c:\ProgramData\anaconda3\envs\genai_longchain\Lib\site-packages\sentence_transformers\cross_encoder\CrossEncoder.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# WARNING:tensorflow:From c:\ProgramData\anaconda3\envs\genai_longchain\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# INTENT: procedural | Needs: rag=True, tools=True, general=True | Confidence: 1.00
# 1. Wcielić się w rolę UX Audytora
#    Goal: Wcielić się w rolę UX Audytora
#    How to execute: method=TOOL, depends_on=[]
#    Component: Audytor UX
#    Component found: True
#    Assign score: 1.00 | low_confidence=False
#    Inputs: ['przekazane makety FIGMY']
#    Outputs: ['context_chunks', 'citations']
#    Success criteria: ['wartościowe wyniki analizy']
#    Fallback: Powtórzyć analizę
#    Rationale:
#      why_method: Domain operation handled by a specialized tool.
#      why_component: Chosen by planner: Audytor UX
# 2. Sprawdzenie listy zmian
#    Goal: Sprawdzenie listy zmian
#    How to execute: method=RAG, depends_on=['S1']
#    Component: Weryfikacja regulaminów i polityk prywatności
#    Component found: True
#    Assign score: 1.00 | low_confidence=False
#    Inputs: ['lista zmian', 'polityka prywatności firmy', 'regulamin']
#    Outputs: ['context_chunks', 'citations']
#    Success criteria: ['wartościowe wyniki sprawdzenia']
#    Fallback: Powtórzyć sprawdzenie
#    Rationale:
#      why_method: Requires domain retrieval or knowledge search.
#      why_component: Chosen by planner: Weryfikacja regulaminów i polityk prywatności
# 3. Przygotowanie raportu
#    Goal: Przygotowanie raportu
#    How to execute: method=TOOL, depends_on=['S2']
#    Component: Raport końcowy
#    Component found: True
#    Assign score: 1.00 | low_confidence=False
#    Inputs: []
#    Outputs: ['final_report']
#    Success criteria: ['wartościowy raport']
#    Fallback: Powtórzyć przygotowanie raportu
#    Rationale:
#      why_method: Domain operation handled by a specialized tool.
#      why_component: Chosen by planner: Raport końcowy
# 4. Zakończenie projektów
#    Goal: Zakończenie projektów
#    How to execute: method=GENERAL, depends_on=['S3']
#    Component: —
#    Component found: False
#    Assign score: 1.00 | low_confidence=False
#    Inputs: []
#    Outputs: []
#    Success criteria: []
#    Fallback: -
#    Rationale:
#      why_method: General reasoning step.
# 5. Wyciągnięcie raportu finansowego
#    Goal: Wyciągnięcie raportu finansowego
#    How to execute: method=TOOL, depends_on=[]
#    Component: Raport końcowy
#    Component found: True
#    Assign score: 0.80 | low_confidence=False
#    Inputs: []
#    Outputs: ['financial_report', 'last_quarter_budget']
#    Success criteria: ['wartościowy raport finansowy']
#    Fallback: Powtórzyć wyciągnięcie raportu
#    Rationale:
#      why_method: Domain operation handled by a specialized tool.
#      why_component: Chosen by planner: Raport końcowy
# 6. Ocenienie kosztów zmian
#    Goal: Ocenienie kosztów zmian
#    How to execute: method=TOOL, depends_on=['S5']
#    Component: Agent kosztorysowy
#    Component found: True
#    Assign score: 1.00 | low_confidence=False
#    Inputs: []
#    Outputs: ['cost_estimate']
#    Success criteria: ['wartościowa ocena kosztów zmian']
#    Fallback: Powtórzyć ocenę kosztów
#    Rationale:
#      why_method: Domain operation handled by a specialized tool.
#      why_component: Chosen by planner: Agent kosztorysowy
# 7. Synthesis
#    Goal: Synthesis
#    How to execute: method=GENERAL, depends_on=['S3', 'S6']
#    Component: Raport końcowy
#    Component found: True
#    Assign score: 1.00 | low_confidence=False
#    Inputs: ['final_report', 'final_decision', 'rationale']
#    Outputs: ['final_report', 'final_decision', 'rationale']
#    Success criteria: ['wartościowy wynik końcowy']
#    Fallback: -
#    Rationale:
#      why_method: General reasoning step.
#      why_component: Chosen by planner: Raport końcowy
#
# --- Supervisor diagnostics ---
# Source: stepwise
# Needs consistency: OK
# DAG violations: ["Duplicate output 'context_chunks' in S1 and S2", "Duplicate output 'citations' in S1 and S2", "Duplicate output 'final_report' in S3 and S7"]
# 1. Wcielić się w rolę UX Audytora
#    Goal: Wcielić się w rolę UX Audytora
#    How to execute: method=TOOL, depends_on=[]
#    Component: Audytor UX
#    Component found: True
#    Assign score: 1.00 | low_confidence=False
#    Inputs: ['przekazane makety FIGMY']
#    Outputs: ['context_chunks', 'citations']
#    Success criteria: ['wartościowe wyniki analizy']
#    Fallback: Powtórzyć analizę
#    Rationale:
#      why_method: Domain operation handled by a specialized tool.
#      why_component: Chosen by planner: Audytor UX
#    Note: missing inputs: ['przekazane makety FIGMY'] (treated as user input or skipped)
#    Invocation: OK
#    Result (output): {"podsumowanie": "Makiety są czytelne, ale brakuje spójności kolorystycznej.", "problemy": [{"id": "contrast", "opis": "Za mały kontrast przycisków.", "priorytet": "średni"}, {"id": "navigation", "opis": "Nieintuicyjne położenie 'Powrót'.", "priorytet": "niski"}], "rekomendacje": ["Zwiększyć kontrast do WCAG AA", "Ujednolicić styl przycisków"], "koszt_szacowany": 4800}
#    Artifacts (produces): {"ux_report": {"podsumowanie": "Makiety są czytelne, ale brakuje spójności kolorystycznej.", "problemy": [{"id": "contrast", "opis": "Za mały kontrast przycisków.", "priorytet": "średni"}, {"id": "navigation", "opis": "Nieintuicyjne położenie 'Powrót'.", "priorytet": "niski"}], "rekomendacje": ["Zwiększyć kontrast do WCAG AA", "Ujednolicić styl przycisków"], "koszt_szacowany": 4800}}
#    Logs: AudytorUX: mock raport.
# 2. Sprawdzenie listy zmian
#    Goal: Sprawdzenie listy zmian
#    How to execute: method=RAG, depends_on=['S1']
#    Component: Weryfikacja regulaminów i polityk prywatności
#    Component found: True
#    Assign score: 1.00 | low_confidence=False
#    Inputs: ['lista zmian', 'polityka prywatności firmy', 'regulamin']
#    Outputs: ['context_chunks', 'citations']
#    Success criteria: ['wartościowe wyniki sprawdzenia']
#    Fallback: Powtórzyć sprawdzenie
#    Rationale:
#      why_method: Requires domain retrieval or knowledge search.
#      why_component: Chosen by planner: Weryfikacja regulaminów i polityk prywatności
#    Note: missing inputs: ['lista zmian', 'polityka prywatności firmy', 'regulamin'] (treated as user input or skipped)
#    Invocation: OK
#    Result (output): {"compliant": true, "policy_violations": [], "requires_dpo_review": false, "notes": "Zgodne."}
#    Artifacts (produces): {"compliance_findings": {"compliant": true, "policy_violations": [], "requires_dpo_review": false, "notes": "Zgodne."}}
#    Logs: Compliance: analiza zmian względem polityk/regulaminów (mock).
# 3. Przygotowanie raportu
#    Goal: Przygotowanie raportu
#    How to execute: method=TOOL, depends_on=['S2']
#    Component: Raport końcowy
#    Component found: True
#    Assign score: 1.00 | low_confidence=False
#    Inputs: []
#    Outputs: ['final_report']
#    Success criteria: ['wartościowy raport']
#    Fallback: Powtórzyć przygotowanie raportu
#    Rationale:
#      why_method: Domain operation handled by a specialized tool.
#      why_component: Chosen by planner: Raport końcowy
#    Invocation: OK
#    Result (output): {"status_pipeline": "completed", "terminated_by": null, "terminate_reason": null, "pm_decision": null, "pm_notes": null, "ux_report": {"podsumowanie": "Makiety są czytelne, ale brakuje spójności kolorystycznej.", "problemy": [{"id": "contrast", "opis": "Za mały kontrast przycisków.", "priorytet": "średni"}, {"id": "navigation", "opis": "Nieintuicyjne położenie 'Powrót'.", "priorytet": "niski"}], "…
#    Artifacts (produces): {"final_report": {"status_pipeline": "completed", "terminated_by": null, "terminate_reason": null, "pm_decision": null, "pm_notes": null, "ux_report": {"podsumowanie": "Makiety są czytelne, ale brakuje spójności kolorystycznej.", "problemy": [{"id": "contrast", "opis": "Za mały kontrast przycisków.", "priorytet": "średni"}, {"id": "navigation", "opis": "Nieintuicyjne położenie 'Powrót'.", "prioryt…
#    Logs: FinalSummary: gotowe.
# 4. Zakończenie projektów
#    Goal: Zakończenie projektów
#    How to execute: method=GENERAL, depends_on=['S3']
#    Component: —
#    Component found: True
#    Assign score: 1.00 | low_confidence=False
#    Inputs: []
#    Outputs: []
#    Success criteria: []
#    Fallback: -
#    Rationale:
#      why_method: General reasoning step.
#    (Default component used: Generalny)
#    Invocation: OK
#    Result (output): "System Mooff składa się z modułów: CRM, Projekty, Faktury, Magazyn, oraz modułów branżowych. Polityka prywatności: Ustawienia → Bezpieczeństwo."
#    Artifacts (produces): {"rag_context": "Dane testowe", "rag_answer": "System Mooff składa się z modułów: CRM, Projekty, Faktury, Magazyn, oraz modułów branżowych. Polityka prywatności: Ustawienia → Bezpieczeństwo.", "citations": [{"doc_id": "policy", "page": 1}, {"doc_id": "architecture", "page": 2}]}
#    Logs: Generalny: zwrócono przykładową odpowiedź.
# 5. Wyciągnięcie raportu finansowego
#    Goal: Wyciągnięcie raportu finansowego
#    How to execute: method=TOOL, depends_on=[]
#    Component: Raport końcowy
#    Component found: True
#    Assign score: 0.80 | low_confidence=False
#    Inputs: []
#    Outputs: ['financial_report', 'last_quarter_budget']
#    Success criteria: ['wartościowy raport finansowy']
#    Fallback: Powtórzyć wyciągnięcie raportu
#    Rationale:
#      why_method: Domain operation handled by a specialized tool.
#      why_component: Chosen by planner: Raport końcowy
#    Invocation: OK
#    Result (output): {"status_pipeline": "completed", "terminated_by": null, "terminate_reason": null, "pm_decision": null, "pm_notes": null, "ux_report": {"podsumowanie": "Makiety są czytelne, ale brakuje spójności kolorystycznej.", "problemy": [{"id": "contrast", "opis": "Za mały kontrast przycisków.", "priorytet": "średni"}, {"id": "navigation", "opis": "Nieintuicyjne położenie 'Powrót'.", "priorytet": "niski"}], "…
#    Artifacts (produces): {"final_report": {"status_pipeline": "completed", "terminated_by": null, "terminate_reason": null, "pm_decision": null, "pm_notes": null, "ux_report": {"podsumowanie": "Makiety są czytelne, ale brakuje spójności kolorystycznej.", "problemy": [{"id": "contrast", "opis": "Za mały kontrast przycisków.", "priorytet": "średni"}, {"id": "navigation", "opis": "Nieintuicyjne położenie 'Powrót'.", "prioryt…
#    Logs: FinalSummary: gotowe.
# 6. Ocenienie kosztów zmian
#    Goal: Ocenienie kosztów zmian
#    How to execute: method=TOOL, depends_on=['S5']
#    Component: Agent kosztorysowy
#    Component found: True
#    Assign score: 1.00 | low_confidence=False
#    Inputs: []
#    Outputs: ['cost_estimate']
#    Success criteria: ['wartościowa ocena kosztów zmian']
#    Fallback: Powtórzyć ocenę kosztów
#    Rationale:
#      why_method: Domain operation handled by a specialized tool.
#      why_component: Chosen by planner: Agent kosztorysowy
#    Invocation: OK
#    Result (output): {"cost_estimate": 4200.0, "currency": "PLN", "method": "mock: base + per_issue"}
#    Artifacts (produces): {"cost_estimate": 4200.0, "cost_estimate_meta": {"cost_estimate": 4200.0, "currency": "PLN", "method": "mock: base + per_issue"}}
#    Logs: Kosztorys: 4200.0 PLN (mock).
# 7. Synthesis
#    Goal: Synthesis
#    How to execute: method=GENERAL, depends_on=['S3', 'S6']
#    Component: Raport końcowy
#    Component found: True
#    Assign score: 1.00 | low_confidence=False
#    Inputs: ['final_report', 'final_decision', 'rationale']
#    Outputs: ['final_report', 'final_decision', 'rationale']
#    Success criteria: ['wartościowy wynik końcowy']
#    Fallback: -
#    Rationale:
#      why_method: General reasoning step.
#      why_component: Chosen by planner: Raport końcowy
#    Note: missing inputs: ['final_decision', 'rationale'] (treated as user input or skipped)
#    Invocation: OK
#    Result (output): {"status_pipeline": "completed", "terminated_by": null, "terminate_reason": null, "pm_decision": null, "pm_notes": null, "ux_report": {"podsumowanie": "Makiety są czytelne, ale brakuje spójności kolorystycznej.", "problemy": [{"id": "contrast", "opis": "Za mały kontrast przycisków.", "priorytet": "średni"}, {"id": "navigation", "opis": "Nieintuicyjne położenie 'Powrót'.", "priorytet": "niski"}], "…
#    Artifacts (produces): {"final_report": {"status_pipeline": "completed", "terminated_by": null, "terminate_reason": null, "pm_decision": null, "pm_notes": null, "ux_report": {"podsumowanie": "Makiety są czytelne, ale brakuje spójności kolorystycznej.", "problemy": [{"id": "contrast", "opis": "Za mały kontrast przycisków.", "priorytet": "średni"}, {"id": "navigation", "opis": "Nieintuicyjne położenie 'Powrót'.", "prioryt…
#    Logs: FinalSummary: gotowe.

# %%
cfg = SupervisorConfig(
    llm_adapter=adapter,
    components=components,
    heuristic_enable=False,
    debug=True,
    pass_temperature=False,
    pass_max_tokens=False,
    resources={
        **resources,
        # plug-in your embedding function for semantic fallback:
        # it must be: callable(str) -> List[float]
        "embed_fn": resources.get("embed_fn"),  # np. embed_manager.embed_text
    },
    fallback_component="Generalny",
    fallback_on_miss=True,

    # Two-stage with stronger assignment
    planner_mode="two_stage",
    plan_retries=2,
    assign_retries=2,
    assign_self_consistency=3,
    assign_threshold=0.50,
    skip_on_low_confidence=False,
    assign_temperature=0.3,      # ważne: unikniesz „pustych” JSON-ów

    # Semantic router
    semantic_fallback=True,
    semantic_weight=0.15,
)

supervisor = IntergraxSupervisor(cfg)
plan = supervisor.plan(query)
supervisor.print_plan(plan)
state = supervisor.execute_plan(plan=plan, query=query, verbose=True)
print("KONIEC")
# Out:
# INTENT: procedural | Needs: rag=False, tools=True, general=True | Confidence: 0.90
# 1. Analiza makiety pod kątem poprawności logicznej i działania aplikacji
#    Goal: Analiza makiety pod kątem poprawności logicznej i działania aplikacji
#    How to execute: method=TOOL, depends_on=[]
#    Component: Audytor UX
#    Component found: True
#    Assign score: 0.80 | low_confidence=False
#    Inputs: ['makiety FIGMY']
#    Outputs: ['context_chunks', 'citations']
#    Success criteria: ['Poprawna analiza makiety']
#    Fallback: Przeprowadzenie dodatkowej analizy
#    Rationale:
#      why_method: Domain operation handled by a specialized tool.
#      why_component: Chosen by planner: Audytor UX
# 2. Sprawdzenie listy zmian
#    Goal: Sprawdzenie listy zmian
#    How to execute: method=TOOL, depends_on=['S1']
#    Component: Weryfikacja regulaminów i polityk prywatności
#    Component found: True
#    Assign score: 1.00 | low_confidence=False
#    Inputs: ['lista zmian', 'polityka prywatności firmy', 'regulaminów']
#    Outputs: ['context_chunks', 'citations']
#    Success criteria: ['Zgodność listy zmian z polityką prywatności i regulaminami']
#    Fallback: Przeprowadzenie dodatkowej analizy
#    Rationale:
#      why_method: Domain operation handled by a specialized tool.
#      why_component: Chosen by planner: Weryfikacja regulaminów i polityk prywatności
# 3. Przygotowanie raportu
#    Goal: Przygotowanie raportu
#    How to execute: method=TOOL, depends_on=['S2']
#    Component: Raport końcowy
#    Component found: True
#    Assign score: 1.00 | low_confidence=False
#    Inputs: ['prior artifacts']
#    Outputs: ['final_report']
#    Success criteria: ['Poprawne przygotowanie raportu']
#    Fallback: Przeprowadzenie dodatkowej analizy
#    Rationale:
#      why_method: Domain operation handled by a specialized tool.
#      why_component: Chosen by planner: Raport końcowy
# 4. Decyzja PM
#    Goal: Decyzja PM
#    How to execute: method=TOOL, depends_on=['S3']
#    Component: Project Manager
#    Component found: True
#    Assign score: 1.00 | low_confidence=False
#    Inputs: ['prior artifacts', "PM's decision"]
#    Outputs: []
#    Success criteria: ['Poprawna decyzja PM']
#    Fallback: Przeprowadzenie dodatkowej analizy
#    Rationale:
#      why_method: Domain operation handled by a specialized tool.
#      why_component: Chosen by planner: Project Manager
# 5. Analiza raportu finansowego
#    Goal: Analiza raportu finansowego
#    How to execute: method=TOOL, depends_on=['S4']
#    Component: Agent kosztorysowy
#    Component found: True
#    Assign score: 1.00 | low_confidence=False
#    Inputs: ['raport finansowy', 'budżet firmy']
#    Outputs: ['financial_report', 'cost_estimate']
#    Success criteria: ['Poprawna analiza raportu finansowego']
#    Fallback: Przeprowadzenie dodatkowej analizy
#    Rationale:
#      why_method: Domain operation handled by a specialized tool.
#      why_component: Chosen by planner: Agent kosztorysowy
# 6. Zatwierdzenie zmian
#    Goal: Zatwierdzenie zmian
#    How to execute: method=GENERAL, depends_on=['S5']
#    Component: Agent kosztorysowy
#    Component found: True
#    Assign score: 1.00 | low_confidence=False
#    Inputs: ['prior artifacts', 'koszt zmian']
#    Outputs: []
#    Success criteria: ['Poprawna decyzja o zatwierdzeniu zmian']
#    Fallback: Przeprowadzenie dodatkowej analizy
#    Rationale:
#      why_method: General reasoning step.
#      why_component: Chosen by planner: Agent kosztorysowy
# 7. Przygotowanie pełnego raportu
#    Goal: Przygotowanie pełnego raportu
#    How to execute: method=TOOL, depends_on=['S6']
#    Component: Raport końcowy
#    Component found: True
#    Assign score: 1.00 | low_confidence=False
#    Inputs: ['prior artifacts']
#    Outputs: ['final_report', 'rationale']
#    Success criteria: ['Poprawne przygotowanie pełnego raportu']
#    Fallback: Przeprowadzenie dodatkowej analizy
#    Rationale:
#      why_method: Domain operation handled by a specialized tool.
#      why_component: Chosen by planner: Raport końcowy
#
# --- Supervisor diagnostics ---
# Source: stepwise
# Needs consistency: OK
# DAG violations: ["Duplicate output 'context_chunks' in S1 and S2", "Duplicate output 'citations' in S1 and S2", "Duplicate output 'final_report' in S3 and S7"]
# 1. Analiza makiety pod kątem poprawności logicznej i działania aplikacji
#    Goal: Analiza makiety pod kątem poprawności logicznej i działania aplikacji
#    How to execute: method=TOOL, depends_on=[]
#    Component: Audytor UX
#    Component found: True
#    Assign score: 0.80 | low_confidence=False
#    Inputs: ['makiety FIGMY']
#    Outputs: ['context_chunks', 'citations']
#    Success criteria: ['Poprawna analiza makiety']
#    Fallback: Przeprowadzenie dodatkowej analizy
#    Rationale:
#      why_method: Domain operation handled by a specialized tool.
#      why_component: Chosen by planner: Audytor UX
#    Note: missing inputs: ['makiety FIGMY'] (treated as user input or skipped)
#    Invocation: OK
#    Result (output): {"podsumowanie": "Makiety są czytelne, ale brakuje spójności kolorystycznej.", "problemy": [{"id": "contrast", "opis": "Za mały kontrast przycisków.", "priorytet": "średni"}, {"id": "navigation", "opis": "Nieintuicyjne położenie 'Powrót'.", "priorytet": "niski"}], "rekomendacje": ["Zwiększyć kontrast do WCAG AA", "Ujednolicić styl przycisków"], "koszt_szacowany": 4800}
#    Artifacts (produces): {"ux_report": {"podsumowanie": "Makiety są czytelne, ale brakuje spójności kolorystycznej.", "problemy": [{"id": "contrast", "opis": "Za mały kontrast przycisków.", "priorytet": "średni"}, {"id": "navigation", "opis": "Nieintuicyjne położenie 'Powrót'.", "priorytet": "niski"}], "rekomendacje": ["Zwiększyć kontrast do WCAG AA", "Ujednolicić styl przycisków"], "koszt_szacowany": 4800}}
#    Logs: AudytorUX: mock raport.
# 2. Sprawdzenie listy zmian
#    Goal: Sprawdzenie listy zmian
#    How to execute: method=TOOL, depends_on=['S1']
#    Component: Weryfikacja regulaminów i polityk prywatności
#    Component found: True
#    Assign score: 1.00 | low_confidence=False
#    Inputs: ['lista zmian', 'polityka prywatności firmy', 'regulaminów']
#    Outputs: ['context_chunks', 'citations']
#    Success criteria: ['Zgodność listy zmian z polityką prywatności i regulaminami']
#    Fallback: Przeprowadzenie dodatkowej analizy
#    Rationale:
#      why_method: Domain operation handled by a specialized tool.
#      why_component: Chosen by planner: Weryfikacja regulaminów i polityk prywatności
#    Note: missing inputs: ['lista zmian', 'polityka prywatności firmy', 'regulaminów'] (treated as user input or skipped)
#    Invocation: OK
#    Result (output): {"compliant": true, "policy_violations": [], "requires_dpo_review": false, "notes": "Zgodne."}
#    Artifacts (produces): {"compliance_findings": {"compliant": true, "policy_violations": [], "requires_dpo_review": false, "notes": "Zgodne."}}
#    Logs: Compliance: analiza zmian względem polityk/regulaminów (mock).
# 3. Przygotowanie raportu
#    Goal: Przygotowanie raportu
#    How to execute: method=TOOL, depends_on=['S2']
#    Component: Raport końcowy
#    Component found: True
#    Assign score: 1.00 | low_confidence=False
#    Inputs: ['prior artifacts']
#    Outputs: ['final_report']
#    Success criteria: ['Poprawne przygotowanie raportu']
#    Fallback: Przeprowadzenie dodatkowej analizy
#    Rationale:
#      why_method: Domain operation handled by a specialized tool.
#      why_component: Chosen by planner: Raport końcowy
#    Note: missing inputs: ['prior artifacts'] (treated as user input or skipped)
#    Invocation: OK
#    Result (output): {"status_pipeline": "completed", "terminated_by": null, "terminate_reason": null, "pm_decision": null, "pm_notes": null, "ux_report": {"podsumowanie": "Makiety są czytelne, ale brakuje spójności kolorystycznej.", "problemy": [{"id": "contrast", "opis": "Za mały kontrast przycisków.", "priorytet": "średni"}, {"id": "navigation", "opis": "Nieintuicyjne położenie 'Powrót'.", "priorytet": "niski"}], "…
#    Artifacts (produces): {"final_report": {"status_pipeline": "completed", "terminated_by": null, "terminate_reason": null, "pm_decision": null, "pm_notes": null, "ux_report": {"podsumowanie": "Makiety są czytelne, ale brakuje spójności kolorystycznej.", "problemy": [{"id": "contrast", "opis": "Za mały kontrast przycisków.", "priorytet": "średni"}, {"id": "navigation", "opis": "Nieintuicyjne położenie 'Powrót'.", "prioryt…
#    Logs: FinalSummary: gotowe.
# 4. Decyzja PM
#    Goal: Decyzja PM
#    How to execute: method=TOOL, depends_on=['S3']
#    Component: Project Manager
#    Component found: True
#    Assign score: 1.00 | low_confidence=False
#    Inputs: ['prior artifacts', "PM's decision"]
#    Outputs: []
#    Success criteria: ['Poprawna decyzja PM']
#    Fallback: Przeprowadzenie dodatkowej analizy
#    Rationale:
#      why_method: Domain operation handled by a specialized tool.
#      why_component: Chosen by planner: Project Manager
#    Note: missing inputs: ['prior artifacts', "PM's decision"] (treated as user input or skipped)
#    Invocation: OK
#    Result (output): {"decision": "accepted", "notes": "Proszę uwzględnić kontrast i spójność kolorów."}
#    Artifacts (produces): {"pm_decision": "accepted", "pm_notes": "Proszę uwzględnić kontrast i spójność kolorów."}
#    Logs: PM: decyzja = accepted
# 5. Analiza raportu finansowego
#    Goal: Analiza raportu finansowego
#    How to execute: method=TOOL, depends_on=['S4']
#    Component: Agent kosztorysowy
#    Component found: True
#    Assign score: 1.00 | low_confidence=False
#    Inputs: ['raport finansowy', 'budżet firmy']
#    Outputs: ['financial_report', 'cost_estimate']
#    Success criteria: ['Poprawna analiza raportu finansowego']
#    Fallback: Przeprowadzenie dodatkowej analizy
#    Rationale:
#      why_method: Domain operation handled by a specialized tool.
#      why_component: Chosen by planner: Agent kosztorysowy
#    Note: missing inputs: ['raport finansowy', 'budżet firmy'] (treated as user input or skipped)
#    Invocation: OK
#    Result (output): {"cost_estimate": 4200.0, "currency": "PLN", "method": "mock: base + per_issue"}
#    Artifacts (produces): {"cost_estimate": 4200.0, "cost_estimate_meta": {"cost_estimate": 4200.0, "currency": "PLN", "method": "mock: base + per_issue"}}
#    Logs: Kosztorys: 4200.0 PLN (mock).
# 6. Zatwierdzenie zmian
#    Goal: Zatwierdzenie zmian
#    How to execute: method=GENERAL, depends_on=['S5']
#    Component: Agent kosztorysowy
#    Component found: True
#    Assign score: 1.00 | low_confidence=False
#    Inputs: ['prior artifacts', 'koszt zmian']
#    Outputs: []
#    Success criteria: ['Poprawna decyzja o zatwierdzeniu zmian']
#    Fallback: Przeprowadzenie dodatkowej analizy
#    Rationale:
#      why_method: General reasoning step.
#      why_component: Chosen by planner: Agent kosztorysowy
#    Note: missing inputs: ['prior artifacts', 'koszt zmian'] (treated as user input or skipped)
#    Invocation: OK
#    Result (output): {"cost_estimate": 4200.0, "currency": "PLN", "method": "mock: base + per_issue"}
#    Artifacts (produces): {"cost_estimate": 4200.0, "cost_estimate_meta": {"cost_estimate": 4200.0, "currency": "PLN", "method": "mock: base + per_issue"}}
#    Logs: Kosztorys: 4200.0 PLN (mock).
# 7. Przygotowanie pełnego raportu
#    Goal: Przygotowanie pełnego raportu
#    How to execute: method=TOOL, depends_on=['S6']
#    Component: Raport końcowy
#    Component found: True
#    Assign score: 1.00 | low_confidence=False
#    Inputs: ['prior artifacts']
#    Outputs: ['final_report', 'rationale']
#    Success criteria: ['Poprawne przygotowanie pełnego raportu']
#    Fallback: Przeprowadzenie dodatkowej analizy
#    Rationale:
#      why_method: Domain operation handled by a specialized tool.
#      why_component: Chosen by planner: Raport końcowy
#    Note: missing inputs: ['prior artifacts'] (treated as user input or skipped)
#    Invocation: OK
#    Result (output): {"status_pipeline": "completed", "terminated_by": null, "terminate_reason": null, "pm_decision": "accepted", "pm_notes": "Proszę uwzględnić kontrast i spójność kolorów.", "ux_report": {"podsumowanie": "Makiety są czytelne, ale brakuje spójności kolorystycznej.", "problemy": [{"id": "contrast", "opis": "Za mały kontrast przycisków.", "priorytet": "średni"}, {"id": "navigation", "opis": "Nieintuicyj…
#    Artifacts (produces): {"final_report": {"status_pipeline": "completed", "terminated_by": null, "terminate_reason": null, "pm_decision": "accepted", "pm_notes": "Proszę uwzględnić kontrast i spójność kolorów.", "ux_report": {"podsumowanie": "Makiety są czytelne, ale brakuje spójności kolorystycznej.", "problemy": [{"id": "contrast", "opis": "Za mały kontrast przycisków.", "priorytet": "średni"}, {"id": "navigation", "op…
#    Logs: FinalSummary: gotowe.
# KONIEC
